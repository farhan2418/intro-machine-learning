# %%
# %pip install seaborn

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 214          215         0       3             Kiernan, Mr. Philip    male
# 583          584         0       1             Ross, Mr. John Hugo    male
# 626          627         0       2  Kirkland, Rev. Charles Leonard    male
# 61            62         1       1             Icard, Miss. Amelie  female
# 771          772         0       3         Jensen, Mr. Niels Peder    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 214   NaN      1      0  367229   7.7500   NaN        Q
# 583  36.0      0      0   13049  40.1250   A10        C
# 626  57.0      0      0  219533  12.3500   NaN        Q
# 61   38.0      0      0  113572  80.0000   B28      NaN
# 771  48.0      0      0  350047   7.8542   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# **Given is a dataset of the actual passenger details travelled in the titanic ship. So here output is the survived column. and we want to predict whether a passenger will survice or not with the available details of the same**

# %%
# sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>
